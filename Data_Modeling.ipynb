# %% [markdown]
# # Data Modeling

# %% [markdown]
# ## Importing Data

# %%
import pandas as pd
df = pd.read_csv('final_df.csv')
df.head()
# Out:
#    Year  Quarter       State  Pct_Telehealth   Real_GDP  Total_Population  \
# 0  2020        1     Alabama          0.0554   222288.8           4903185
# 1  2020        1      Alaska          0.0758    50332.8            731545
# 2  2020        1     Arizona          0.0617   365027.7           7278717
# 3  2020        1    Arkansas          0.0472   128340.9           3017804
# 4  2020        1  California          0.0915  2933320.2          39512223
#
#    Total_Male_Population%  Total_Female_Population%  Population_Under5%  \
# 0                    48.3                      51.7                 5.8
# 1                    52.0                      48.0                 7.0
# 2                    49.7                      50.3                 5.9
# 3                    48.9                      51.1                 6.1
# 4                    49.7                      50.3                 6.0
#
#    Population5_17%  ...  Black  Hispanic  Asian  \
# 0             16.3  ...  0.265     0.044  0.014
# 1             17.6  ...  0.022     0.070  0.060
# 2             16.7  ...  0.043     0.318  0.033
# 3             17.1  ...  0.152     0.078  0.016
# 4             16.5  ...  0.053     0.395  0.147
#
#    American Indian or Alaska Native  Multiple Races     Region     pos  \
# 0                             0.004           0.019      South  0.0965
# 1                             0.151           0.083       West  0.0340
# 2                             0.039           0.024  Southwest  0.0764
# 3                             0.006           0.024      South  0.0742
# 4                             0.004           0.033       West  0.1210
#
#       neu     neg  compound
# 0  0.7927  0.1109  -0.01450
# 1  0.8955  0.0705  -0.18579
# 2  0.8259  0.0977  -0.16932
# 3  0.8370  0.0889   0.02960
# 4  0.8126  0.0665   0.07139
#
# [5 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Year                               816 non-null    int64
#  1   Quarter                            816 non-null    int64
#  2   State                              816 non-null    object
#  3   Pct_Telehealth                     816 non-null    float64
#  4   Real_GDP                           816 non-null    float64
#  5   Total_Population                   816 non-null    int64
#  6   Total_Male_Population%             816 non-null    float64
#  7   Total_Female_Population%           816 non-null    float64
#  8   Population_Under5%                 816 non-null    float64
#  9   Population5_17%                    816 non-null    float64
#  10  Population18_24%                   816 non-null    float64
#  11  Population25_34%                   816 non-null    float64
#  12  Population35_44%                   816 non-null    float64
#  13  Population45_54%                   816 non-null    float64
#  14  Population55_64%                   816 non-null    float64
#  15  Population65_74%                   816 non-null    float64
#  16  Population_Over75%                 816 non-null    float64
#  17  Less_Than_High_School_Diploma%     816 non-null    float64
#  18  High_School_Graduate%              816 non-null    float64
#  19  Some_College_or_Associate Degree%  816 non-null    float64
#  20  Bachelor_Degree%                   816 non-null    float64
#  21  Graduate_Or_Professional_Degree%   816 non-null    float64
#  22  UnemploymentRate%                  816 non-null    float64
#  23  Private_Health_Insurance%          816 non-null    float64
#  24  Public_Health_Insurance_Coverage%  816 non-null    float64
#  25  No_Health_Insurance_Coverage%      816 non-null    float64
#  26  Povery_Rate%                       816 non-null    float64
#  27  White                              816 non-null    float64
#  28  Black                              816 non-null    float64
#  29  Hispanic                           816 non-null    float64
#  30  Asian                              816 non-null    float64
#  31  American Indian or Alaska Native   816 non-null    float64
#  32  Multiple Races                     816 non-null    float64
#  33  Region                             816 non-null    object
#  34  pos                                816 non-null    float64
#  35  neu                                816 non-null    float64
#  36  neg                                816 non-null    float64
#  37  compound                           816 non-null    float64
# dtypes: float64(33), int64(3), object(2)
# memory usage: 242.4+ KB

# %%
df.isna().sum()
# Out:
# Year                                 0
# Quarter                              0
# State                                0
# Pct_Telehealth                       0
# Real_GDP                             0
# Total_Population                     0
# Total_Male_Population%               0
# Total_Female_Population%             0
# Population_Under5%                   0
# Population5_17%                      0
# Population18_24%                     0
# Population25_34%                     0
# Population35_44%                     0
# Population45_54%                     0
# Population55_64%                     0
# Population65_74%                     0
# Population_Over75%                   0
# Less_Than_High_School_Diploma%       0
# High_School_Graduate%                0
# Some_College_or_Associate Degree%    0
# Bachelor_Degree%                     0
# Graduate_Or_Professional_Degree%     0
# UnemploymentRate%                    0
# Private_Health_Insurance%            0
# Public_Health_Insurance_Coverage%    0
# No_Health_Insurance_Coverage%        0
# Povery_Rate%                         0
# White                                0
# Black                                0
# Hispanic                             0
# Asian                                0
# American Indian or Alaska Native     0
# Multiple Races                       0
# Region                               0
# pos                                  0
# neu                                  0
# neg                                  0
# compound                             0
# dtype: int64

# %%
# Create a boolean mask for the condition
mask = (df['Year'] == 2023) & ((df['Quarter'] == 3) | (df['Quarter'] == 4))

# Create the new dataset
df_2023_Q4 = df[mask].copy()  # Use .copy() to avoid SettingWithCopyWarning

# Remove the rows from the original dataset
df = df[~mask]

# %%
df.drop(columns = ['State'], inplace = True)
df_2023_Q4.drop(columns = ['State'], inplace = True)
# Out:
# <ipython-input-72-d57f84e191ec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns = ['State'], inplace = True)

# %%
df = pd.get_dummies(df, columns = ['Region']).astype(int)
df_2023_Q4 = pd.get_dummies(df_2023_Q4, columns = ['Region']).astype(int)

# %%
## X matrix and y vector
X_train = df.drop(columns = ['Pct_Telehealth'])
y_train = df['Pct_Telehealth']

X_test = df_2023_Q4.drop(columns = ['Pct_Telehealth'])
y_test = df_2023_Q4['Pct_Telehealth']

# %% [markdown]
# ## XGBoost

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV

xgb = XGBRegressor()
param_grid = {
    "learning_rate" : [0.01, 0.1, 0.2],
    "max_depth" : [3, 6, 9],
    "n_estimators" : [50, 100, 150]
}

grid_search_xgb = GridSearchCV(xgb, param_grid, cv = 5, n_jobs = -1)
grid_search_xgb.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 6, 9],
#                          'n_estimators': [50, 100, 150]})

# %%
print(grid_search_xgb.best_params_)
# Out:
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Predict on the test set using the best estimator
y_pred = grid_search_xgb.best_estimator_.predict(X_test)

# Calculate R-squared
r2 = r2_score(y_test, y_pred)
print(f"R-squared: {r2}")

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f"RMSE: {rmse}")
# Out:
# R-squared: 1.0
# RMSE: 0.0

# %% [markdown]
# ## Regression

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 102 entries, 714 to 815
# Data columns (total 40 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Year                               102 non-null    int64
#  1   Quarter                            102 non-null    int64
#  2   Real_GDP                           102 non-null    int64
#  3   Total_Population                   102 non-null    int64
#  4   Total_Male_Population%             102 non-null    int64
#  5   Total_Female_Population%           102 non-null    int64
#  6   Population_Under5%                 102 non-null    int64
#  7   Population5_17%                    102 non-null    int64
#  8   Population18_24%                   102 non-null    int64
#  9   Population25_34%                   102 non-null    int64
#  10  Population35_44%                   102 non-null    int64
#  11  Population45_54%                   102 non-null    int64
#  12  Population55_64%                   102 non-null    int64
#  13  Population65_74%                   102 non-null    int64
#  14  Population_Over75%                 102 non-null    int64
#  15  Less_Than_High_School_Diploma%     102 non-null    int64
#  16  High_School_Graduate%              102 non-null    int64
#  17  Some_College_or_Associate Degree%  102 non-null    int64
#  18  Bachelor_Degree%                   102 non-null    int64
#  19  Graduate_Or_Professional_Degree%   102 non-null    int64
#  20  UnemploymentRate%                  102 non-null    int64
#  21  Private_Health_Insurance%          102 non-null    int64
#  22  Public_Health_Insurance_Coverage%  102 non-null    int64
#  23  No_Health_Insurance_Coverage%      102 non-null    int64
#  24  Povery_Rate%                       102 non-null    int64
#  25  White                              102 non-null    int64
#  26  Black                              102 non-null    int64
#  27  Hispanic                           102 non-null    int64
#  28  Asian                              102 non-null    int64
#  29  American Indian or Alaska Native   102 non-null    int64
#  30  Multiple Races                     102 non-null    int64
#  31  pos                                102 non-null    int64
#  32  neu                                102 non-null    int64
#  33  neg                                102 non-null    int64
#  34  compound                           102 non-null    int64
#  35  Region_Midwest                     102 non-null    int64
#  36  Region_Northeast                   102 non-null    int64
#  37  Region_South                       102 non-null    int64
#  38  Region_Southwest                   102 non-null    int64
#  39  Region_West                        102 non-null    int64
# dtypes: int64(40)
# memory usage: 32.7 KB

# %%
import statsmodels.api as sm
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np

# Print the shapes before proceeding
print(f"Shape of X_train: {X_train.shape}")
print(f"Shape of X_test: {X_test.shape}")

# Add a constant to the independent variables (only X_train and X_test)
X_train_sm = sm.add_constant(X_train)
X_test_sm = sm.add_constant(X_test)

# Print the shapes of the transformed data
print(f"Shape of X_train_sm: {X_train_sm.shape}")
print(f"Shape of X_test_sm: {X_test_sm.shape}")

# Fit the linear regression model
model = sm.OLS(y_train, X_train_sm).fit()

# Print the model summary
print(model.summary())

# Make predictions on the test set
y_pred_sm = model.predict(X_test_sm)

# Evaluate the model
r2_sm = r2_score(y_test, y_pred_sm)
rmse_sm = np.sqrt(mean_squared_error(y_test, y_pred_sm))

print(f"Linear Regression R-squared: {r2_sm}")
print(f"Linear Regression RMSE: {rmse_sm}")
# Out:
# Shape of X_train: (714, 40)
# Shape of X_test: (102, 40)
# Shape of X_train_sm: (714, 41)
# Shape of X_test_sm: (102, 40)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Pct_Telehealth   R-squared:                         nan
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):                nan
# Time:                        19:53:48   Log-Likelihood:                    inf
# No. Observations:                 714   AIC:                              -inf
# Df Residuals:                     684   BIC:                              -inf
# Df Model:                          29
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                      0          0        nan        nan           0           0
# Year                                       0          0        nan        nan           0           0
# Quarter                                    0          0        nan        nan           0           0
# Real_GDP                                   0          0        nan        nan           0           0
# Total_Population                           0          0        nan        nan           0           0
# Total_Male_Population%                     0          0        nan        nan           0           0
# Total_Female_Population%                   0          0        nan        nan           0           0
# Population_Under5%                         0          0        nan        nan           0           0
# Population5_17%                            0          0        nan        nan           0           0
# Population18_24%                           0          0        nan        nan           0           0
# Population25_34%                           0          0        nan        nan           0           0
# Population35_44%                           0          0        nan        nan           0           0
# Population45_54%                           0          0        nan        nan           0           0
# Population55_64%                           0          0        nan        nan           0           0
# Population65_74%                           0          0        nan        nan           0           0
# Population_Over75%                         0          0        nan        nan           0           0
# Less_Than_High_School_Diploma%             0          0        nan        nan           0           0
# High_School_Graduate%                      0          0        nan        nan           0           0
# Some_College_or_Associate Degree%          0          0        nan        nan           0           0
# Bachelor_Degree%                           0          0        nan        nan           0           0
# Graduate_Or_Professional_Degree%           0          0        nan        nan           0           0
# UnemploymentRate%                          0          0        nan        nan           0           0
# Private_Health_Insurance%                  0          0        nan        nan           0           0
# Public_Health_Insurance_Coverage%          0          0        nan        nan           0           0
# No_Health_Insurance_Coverage%              0          0        nan        nan           0           0
# Povery_Rate%                               0          0        nan        nan           0           0
# White                                      0          0        nan        nan           0           0
# Black                                      0          0        nan        nan           0           0
# Hispanic                                   0          0        nan        nan           0           0
# Asian                                      0          0        nan        nan           0           0
# American Indian or Alaska Native           0          0        nan        nan           0           0
# Multiple Races                             0          0        nan        nan           0           0
# pos                                        0          0        nan        nan           0           0
# neu                                        0          0        nan        nan           0           0
# neg                                        0          0        nan        nan           0           0
# compound                                   0          0        nan        nan           0           0
# Region_Midwest                             0          0        nan        nan           0           0
# Region_Northeast                           0          0        nan        nan           0           0
# Region_South                               0          0        nan        nan           0           0
# Region_Southwest                           0          0        nan        nan           0           0
# Region_West                                0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                     nan
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                  nan
# Skew:                             nan   Prob(JB):                          nan
# Kurtosis:                         nan   Cond. No.                     1.34e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.85e-16. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py:1871: RuntimeWarning: invalid value encountered in scalar divide
#   return self.mse_model/self.mse_resid
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py:955: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# /usr/local/lib/python3.10/dist-packages/statsmodels/stats/stattools.py:50: RuntimeWarning: invalid value encountered in scalar divide
#   dw = np.sum(diff_resids**2, axis=axis) / np.sum(resids**2, axis=axis)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-2d5d8aa23d9e> in <cell line: 24>()
#      22
#      23 # Make predictions on the test set
# ---> 24 y_pred_sm = model.predict(X_test_sm)
#      25
#      26 # Evaluate the model
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py in predict(self, exog, transform, *args, **kwargs)
#    1172                                                         transform=transform)
#    1173
# -> 1174         predict_results = self.model.predict(self.params, exog, *args,
#    1175                                              **kwargs)
#    1176
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py in predict(self, params, exog)
#     407             exog = self.exog
#     408
# --> 409         return np.dot(exog, params)
#     410
#     411     def get_distribution(self, params, scale, exog=None, dist_class=None):
#
# ValueError: shapes (102,40) and (41,) not aligned: 40 (dim 1) != 41 (dim 0)

# %%
X_test_sm = sm.add_constant(X_test)

# %%
X_test_sm.shape
# Out:
# (102, 40)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 714 entries, 0 to 713
# Data columns (total 40 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Year                               714 non-null    int64
#  1   Quarter                            714 non-null    int64
#  2   Real_GDP                           714 non-null    int64
#  3   Total_Population                   714 non-null    int64
#  4   Total_Male_Population%             714 non-null    int64
#  5   Total_Female_Population%           714 non-null    int64
#  6   Population_Under5%                 714 non-null    int64
#  7   Population5_17%                    714 non-null    int64
#  8   Population18_24%                   714 non-null    int64
#  9   Population25_34%                   714 non-null    int64
#  10  Population35_44%                   714 non-null    int64
#  11  Population45_54%                   714 non-null    int64
#  12  Population55_64%                   714 non-null    int64
#  13  Population65_74%                   714 non-null    int64
#  14  Population_Over75%                 714 non-null    int64
#  15  Less_Than_High_School_Diploma%     714 non-null    int64
#  16  High_School_Graduate%              714 non-null    int64
#  17  Some_College_or_Associate Degree%  714 non-null    int64
#  18  Bachelor_Degree%                   714 non-null    int64
#  19  Graduate_Or_Professional_Degree%   714 non-null    int64
#  20  UnemploymentRate%                  714 non-null    int64
#  21  Private_Health_Insurance%          714 non-null    int64
#  22  Public_Health_Insurance_Coverage%  714 non-null    int64
#  23  No_Health_Insurance_Coverage%      714 non-null    int64
#  24  Povery_Rate%                       714 non-null    int64
#  25  White                              714 non-null    int64
#  26  Black                              714 non-null    int64
#  27  Hispanic                           714 non-null    int64
#  28  Asian                              714 non-null    int64
#  29  American Indian or Alaska Native   714 non-null    int64
#  30  Multiple Races                     714 non-null    int64
#  31  pos                                714 non-null    int64
#  32  neu                                714 non-null    int64
#  33  neg                                714 non-null    int64
#  34  compound                           714 non-null    int64
#  35  Region_Midwest                     714 non-null    int64
#  36  Region_Northeast                   714 non-null    int64
#  37  Region_South                       714 non-null    int64
#  38  Region_Southwest                   714 non-null    int64
#  39  Region_West                        714 non-null    int64
# dtypes: int64(40)
# memory usage: 228.7 KB

# %%
X_test_sm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 102 entries, 714 to 815
# Data columns (total 40 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Year                               102 non-null    int64
#  1   Quarter                            102 non-null    int64
#  2   Real_GDP                           102 non-null    int64
#  3   Total_Population                   102 non-null    int64
#  4   Total_Male_Population%             102 non-null    int64
#  5   Total_Female_Population%           102 non-null    int64
#  6   Population_Under5%                 102 non-null    int64
#  7   Population5_17%                    102 non-null    int64
#  8   Population18_24%                   102 non-null    int64
#  9   Population25_34%                   102 non-null    int64
#  10  Population35_44%                   102 non-null    int64
#  11  Population45_54%                   102 non-null    int64
#  12  Population55_64%                   102 non-null    int64
#  13  Population65_74%                   102 non-null    int64
#  14  Population_Over75%                 102 non-null    int64
#  15  Less_Than_High_School_Diploma%     102 non-null    int64
#  16  High_School_Graduate%              102 non-null    int64
#  17  Some_College_or_Associate Degree%  102 non-null    int64
#  18  Bachelor_Degree%                   102 non-null    int64
#  19  Graduate_Or_Professional_Degree%   102 non-null    int64
#  20  UnemploymentRate%                  102 non-null    int64
#  21  Private_Health_Insurance%          102 non-null    int64
#  22  Public_Health_Insurance_Coverage%  102 non-null    int64
#  23  No_Health_Insurance_Coverage%      102 non-null    int64
#  24  Povery_Rate%                       102 non-null    int64
#  25  White                              102 non-null    int64
#  26  Black                              102 non-null    int64
#  27  Hispanic                           102 non-null    int64
#  28  Asian                              102 non-null    int64
#  29  American Indian or Alaska Native   102 non-null    int64
#  30  Multiple Races                     102 non-null    int64
#  31  pos                                102 non-null    int64
#  32  neu                                102 non-null    int64
#  33  neg                                102 non-null    int64
#  34  compound                           102 non-null    int64
#  35  Region_Midwest                     102 non-null    int64
#  36  Region_Northeast                   102 non-null    int64
#  37  Region_South                       102 non-null    int64
#  38  Region_Southwest                   102 non-null    int64
#  39  Region_West                        102 non-null    int64
# dtypes: int64(40)
# memory usage: 32.7 KB
