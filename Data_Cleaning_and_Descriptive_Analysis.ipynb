# %% [markdown]
# ## **Medicare Telehealth Trends Dataset**

# %%
import pandas as pd
import numpy as np

telehealth = pd.read_csv("Medicare_Telehealth_Trends_Q1_2024.csv")
telehealth.head()
# Out:
#    Year  quarter Bene_Geo_Desc Bene_Mdcd_Mdcr_Enrl_Stus Bene_Race_Desc  \
# 0  2020  Overall      National                      All            All
# 1  2020  Overall      National                      All            All
# 2  2020  Overall      National                      All            All
# 3  2020  Overall      National                      All            All
# 4  2020  Overall      National                      All            All
#
#   Bene_Sex_Desc Bene_Mdcr_Entlmt_Stus Bene_Age_Desc Bene_RUCA_Desc  \
# 0           All                   All           All            All
# 1           All                   All           All          Rural
# 2           All                   All           All          Urban
# 3           All                   All           All        Unknown
# 4           All                   All          0-64            All
#
#    Total_Bene_TH_Elig  Total_PartB_Enrl  Total_Bene_Telehealth  Pct_Telehealth
# 0          30946785.0      3.224489e+07             14826919.0          0.4791
# 1           7179538.0      7.490301e+06              2858284.0          0.3981
# 2          23696871.0      2.462914e+07             11944230.0          0.5040
# 3                 NaN               NaN                    NaN             NaN
# 4           4088345.0      4.291403e+06              2322324.0          0.5680

# %%
telehealth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25284 entries, 0 to 25283
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      25284 non-null  int64
#  1   quarter                   25284 non-null  object
#  2   Bene_Geo_Desc             25284 non-null  object
#  3   Bene_Mdcd_Mdcr_Enrl_Stus  25284 non-null  object
#  4   Bene_Race_Desc            25284 non-null  object
#  5   Bene_Sex_Desc             25284 non-null  object
#  6   Bene_Mdcr_Entlmt_Stus     25284 non-null  object
#  7   Bene_Age_Desc             25284 non-null  object
#  8   Bene_RUCA_Desc            25284 non-null  object
#  9   Total_Bene_TH_Elig        22607 non-null  float64
#  10  Total_PartB_Enrl          22607 non-null  float64
#  11  Total_Bene_Telehealth     22561 non-null  float64
#  12  Pct_Telehealth            22559 non-null  float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 2.5+ MB

# %%
telehealth.shape
# Out:
# (25284, 13)

# %%
telehealth.nunique()
# Out:
# Year                            5
# quarter                         5
# Bene_Geo_Desc                  56
# Bene_Mdcd_Mdcr_Enrl_Stus        3
# Bene_Race_Desc                  7
# Bene_Sex_Desc                   3
# Bene_Mdcr_Entlmt_Stus           4
# Bene_Age_Desc                   5
# Bene_RUCA_Desc                  4
# Total_Bene_TH_Elig          20955
# Total_PartB_Enrl            22209
# Total_Bene_Telehealth       17382
# Pct_Telehealth               5234
# dtype: int64

# %%
telehealth.isna().sum()
# Out:
# Year                           0
# quarter                        0
# Bene_Geo_Desc                  0
# Bene_Mdcd_Mdcr_Enrl_Stus       0
# Bene_Race_Desc                 0
# Bene_Sex_Desc                  0
# Bene_Mdcr_Entlmt_Stus          0
# Bene_Age_Desc                  0
# Bene_RUCA_Desc                 0
# Total_Bene_TH_Elig          2677
# Total_PartB_Enrl            2677
# Total_Bene_Telehealth       2723
# Pct_Telehealth              2725
# dtype: int64

# %%
# rename Bene_Geo_Desc to Geography Description, Bene_Mdcd_Mdcr_Enrl_Stus to  Enrollment Description, Bene_Race_Desc to race, Bene_Sex_Desc to sex,
# Bene_Mdcr_Entlmt_Stus to Entitlement Status, Bene_Age_Desc to age, Bene_RUCA_Desc to  Rural/Urban Status, Total_Bene_TH_Elig to Total Telehealth Eligible Users,
# Total_PartB_Enrl to Total Medicare Part B Enrollment, and Total_Bene_Telehealth to Total Telehealth Users

# Rename columns
telehealth = telehealth.rename(columns={
    'quarter': 'Quarter',
    'Bene_Geo_Desc': 'Geography',
    'Bene_Mdcd_Mdcr_Enrl_Stus': 'Enrollment Description',
    'Bene_Race_Desc': 'Race',
    'Bene_Sex_Desc': 'Sex',
    'Bene_Mdcr_Entlmt_Stus': 'Entitlement Status',
    'Bene_Age_Desc': 'Age',
    'Bene_RUCA_Desc': 'Rural/Urban Status',
    'Total_Bene_TH_Elig': 'Total Telehealth Eligible Users',
    'Total_PartB_Enrl': 'Total Medicare Part B Enrollment',
    'Total_Bene_Telehealth': 'Total Telehealth Users'
})

telehealth.head()
# Out:
#    Year  Quarter Geography Enrollment Description Race  Sex  \
# 0  2020  Overall  National                    All  All  All
# 1  2020  Overall  National                    All  All  All
# 2  2020  Overall  National                    All  All  All
# 3  2020  Overall  National                    All  All  All
# 4  2020  Overall  National                    All  All  All
#
#   Entitlement Status   Age Rural/Urban Status  \
# 0                All   All                All
# 1                All   All              Rural
# 2                All   All              Urban
# 3                All   All            Unknown
# 4                All  0-64                All
#
#    Total Telehealth Eligible Users  Total Medicare Part B Enrollment  \
# 0                       30946785.0                      3.224489e+07
# 1                        7179538.0                      7.490301e+06
# 2                       23696871.0                      2.462914e+07
# 3                              NaN                               NaN
# 4                        4088345.0                      4.291403e+06
#
#    Total Telehealth Users  Pct_Telehealth
# 0              14826919.0          0.4791
# 1               2858284.0          0.3981
# 2              11944230.0          0.5040
# 3                     NaN             NaN
# 4               2322324.0          0.5680

# %%
# New data set where national is NOT the geography description
telehealth = telehealth[telehealth['Geography'] != 'National']

# Filter for rows where specified columns are 'All'
telehealth = telehealth[
    (telehealth['Enrollment Description'] == 'All') &
    (telehealth['Race'] == 'All') &
    (telehealth['Sex'] == 'All') &
    (telehealth['Entitlement Status'] == 'All') &
    (telehealth['Age'] == 'All') &
    (telehealth['Rural/Urban Status'] == 'All')
]

telehealth = telehealth[telehealth['Quarter'] != 'Overall']

# removing 2024 since it is a partial year and doesn't include all quarters
telehealth = telehealth[telehealth['Year'] != 2024]

## remove all the unneeded columns
telehealth = telehealth.drop(['Enrollment Description', 'Race', 'Sex',
                             'Entitlement Status', 'Age', 'Rural/Urban Status'], axis = 1)

telehealth.head()
# Out:
#       Year Quarter   Geography  Total Telehealth Eligible Users  \
# 1720  2020       1     Alabama                         393549.0
# 1740  2020       1      Alaska                          54569.0
# 1760  2020       1     Arizona                         508632.0
# 1780  2020       1    Arkansas                         308190.0
# 1800  2020       1  California                        2119057.0
#
#       Total Medicare Part B Enrollment  Total Telehealth Users  Pct_Telehealth
# 1720                      5.082080e+05                 21796.0          0.0554
# 1740                      8.833933e+04                  4139.0          0.0758
# 1760                      6.788920e+05                 31362.0          0.0617
# 1780                      4.092010e+05                 14549.0          0.0472
# 1800                      2.918656e+06                193877.0          0.0915

# %%
telehealth['Geography'].unique()

# filter out 'Missing Data', 'Puerto Rico', 'Territories', 'Virgin Islands'
telehealth = telehealth[~telehealth['Geography'].isin(['Missing Data', 'Puerto Rico', 'Territories', 'Virgin Islands'])]

# rename Distict Of Columbia to District of Columbia
telehealth['Geography'] = telehealth['Geography'].replace('District Of Columbia', 'District of Columbia')

telehealth['Geography'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
# correct shape = 51 states * 4 quarters * 4 years (2020-2023)
telehealth.shape
# Out:
# (816, 7)

# %%
telehealth.isna().sum()
# Out:
# Year                                0
# Quarter                             0
# Geography                           0
# Total Telehealth Eligible Users     0
# Total Medicare Part B Enrollment    0
# Total Telehealth Users              0
# Pct_Telehealth                      0
# dtype: int64

# %%
# remove variables that we won't use in our analysis
telehealth = telehealth.drop(['Total Telehealth Eligible Users',
                              'Total Medicare Part B Enrollment',
                              'Total Telehealth Users'], axis = 1)

# %% [markdown]
# ## **Economic Variables**

# %%
# rename telehealth data set to telehealth_data, making a duplicate copy
telehealth_data = telehealth.copy()

# %%
data = pd.read_csv("Economic_Factors.csv")

# Descriptions to filter
descriptions = [
    "Real GDP (millions of chained 2017 dollars) 1/"
]

# Clean and filter the data
# Strip extra spaces in the 'Description' column
data['Description'] = data['Description'].str.strip()

# Retain only rows with valid descriptions and relevant years
years_to_keep = [str(year) for year in range(2020, 2024)]  # Keep data for years 2020-2023
columns_to_keep = ['GeoName', 'Description'] + years_to_keep
filtered_data = data.loc[data['Description'].isin(descriptions), columns_to_keep]

# Reshape the data: convert years from columns to rows
melted_data = filtered_data.melt(
    id_vars=['GeoName', 'Description'],
    var_name='Year',
    value_name='Value'
)

# Pivot the table so each description becomes a separate column
pivoted_data = melted_data.pivot(
    index=['GeoName', 'Year'],
    columns='Description',
    values='Value'
).reset_index()

# Clean up column names
pivoted_data.columns.name = None  # Remove column name grouping
pivoted_data = pivoted_data.rename_axis(None, axis=1)  # Remove the index axis name

# Final cleaned and pivoted DataFrame
pivoted_data.head()
# Out:
#    GeoName  Year Real GDP (millions of chained 2017 dollars) 1/
# 0  Alabama  2020                                       222288.8
# 1  Alabama  2021                                       233726.6
# 2  Alabama  2022                                       238556.5
# 3  Alabama  2023                                       245354.7
# 4   Alaska  2020                                        50332.8

# %%
# Ensure both Year columns are converted to integers for consistency
telehealth_data['Year'] = telehealth_data['Year'].astype(int)
pivoted_data['Year'] = pivoted_data['Year'].astype(int)

# Re-perform the merge with consistent Year types
merged_data_updated = pd.merge(
    telehealth_data,
    pivoted_data,
    left_on=['Geography', 'Year'],
    right_on=['GeoName', 'Year'],
    how='left'
)
merged_data_updated.drop(columns=['GeoName'], inplace=True)

# %%
merged_data_updated.head()
# Out:
#    Year Quarter   Geography  Pct_Telehealth  \
# 0  2020       1     Alabama          0.0554
# 1  2020       1      Alaska          0.0758
# 2  2020       1     Arizona          0.0617
# 3  2020       1    Arkansas          0.0472
# 4  2020       1  California          0.0915
#
#   Real GDP (millions of chained 2017 dollars) 1/
# 0                                       222288.8
# 1                                        50332.8
# 2                                       365027.7
# 3                                       128340.9
# 4                                      2933320.2

# %%
# rename column so it is easier to work with
merged_data_updated = merged_data_updated.rename(columns={'Real GDP (millions of chained 2017 dollars) 1/': 'Real_GDP'})

# convert Real_GDP to a float variable
merged_data_updated['Real_GDP'] = merged_data_updated['Real_GDP'].astype(float)

# %% [markdown]
# ## **Demographic Variables**

# %%
import pandas as pd
import numpy as np

merged_data_updated.head()
# Out:
#    Year Quarter   Geography  Pct_Telehealth   Real_GDP
# 0  2020       1     Alabama          0.0554   222288.8
# 1  2020       1      Alaska          0.0758    50332.8
# 2  2020       1     Arizona          0.0617   365027.7
# 3  2020       1    Arkansas          0.0472   128340.9
# 4  2020       1  California          0.0915  2933320.2

# %%
merged_data_updated.shape
# correct amount of rows
# Out:
# (816, 5)

# %%
# writing lists for looping and renaming purposes
filenames = ['2019_Health_Demographics.csv', '2021_Health_Demographics.csv', '2022_Health_Demographics.csv', '2023_Health_Demographics.csv']
years = ['2020', '2021', '2022', '2023']

new_columns = ['State', 'Total_Population', 'Total_Male_Population%', 'Total_Female_Population%', 'Population_Under5%',
               'Population5_17%', 'Population18_24%', 'Population25_34%', 'Population35_44%',
               'Population45_54%', 'Population55_64%', 'Population65_74%', 'Population_Over75%',
               'Less_Than_High_School_Diploma%', 'High_School_Graduate%', 'Some_College_or_Associate Degree%',
               'Bachelor_Degree%', 'Graduate_Or_Professional_Degree%', 'UnemploymentRate%', 'Private_Health_Insurance%',
               'Public_Health_Insurance_Coverage%', 'No_Health_Insurance_Coverage%', 'Povery_Rate%']

# %%
# Create a dictionary to hold datasets
datasets = {}

# Iterate through filenames and years simultaneously
for file, year in zip(filenames, years):
    datasets[year] = pd.read_csv(file)
    datasets[year].columns = new_columns

    # consolidate the number of rows
    datasets[year].loc[datasets[year]['State'].str.contains('\xa0\xa0\xa0\xa0Total population|\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Estimate', na=False), 'State'] = np.nan

    # forward fill the 'State' column with the appropriate State name
    datasets[year]['State'] = datasets[year]['State'].fillna(method='ffill')

    # drop NA values
    datasets[year] = datasets[year].dropna()

    # reset the index
    datasets[year] = datasets[year].reset_index(drop=True)

    # create a new column with the year
    datasets[year]['Year'] = year

# append together dataframes
demographics2020 = datasets['2020']
demographics2021 = datasets['2021']
demographics2022 = datasets['2022']
demographics2023 = datasets['2023']

# Append/stack rows
demographics = pd.concat([demographics2020, demographics2021, demographics2022, demographics2023], axis=0)
# Out:
# <ipython-input-79-a50939452b53>:13: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   datasets[year]['State'] = datasets[year]['State'].fillna(method='ffill')
# <ipython-input-79-a50939452b53>:13: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   datasets[year]['State'] = datasets[year]['State'].fillna(method='ffill')
# <ipython-input-79-a50939452b53>:13: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   datasets[year]['State'] = datasets[year]['State'].fillna(method='ffill')
# <ipython-input-79-a50939452b53>:13: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   datasets[year]['State'] = datasets[year]['State'].fillna(method='ffill')

# %%
# remove columns with percentage sign in it and transform into float type

columns_with_percent = ['Total_Male_Population%', 'Total_Female_Population%', 'Population_Under5%',
               'Population5_17%', 'Population18_24%', 'Population25_34%', 'Population35_44%',
               'Population45_54%', 'Population55_64%', 'Population65_74%', 'Population_Over75%',
               'Less_Than_High_School_Diploma%', 'High_School_Graduate%', 'Some_College_or_Associate Degree%',
               'Bachelor_Degree%', 'Graduate_Or_Professional_Degree%', 'UnemploymentRate%', 'Private_Health_Insurance%',
               'Public_Health_Insurance_Coverage%', 'No_Health_Insurance_Coverage%', 'Povery_Rate%']

demographics[columns_with_percent] = demographics[columns_with_percent].applymap(lambda x: float(x.rstrip('%')))

# for percentage columns, move the decimal back two places to convert to fractions
demographics[columns_with_percent] = demographics[columns_with_percent] / 100

# remove the commas in Total_Population column
demographics['Total_Population'] = demographics['Total_Population'].str.replace(',', '')
# Out:
# <ipython-input-80-534bc2227f60>:10: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   demographics[columns_with_percent] = demographics[columns_with_percent].applymap(lambda x: float(x.rstrip('%')))

# %%
demographics.head()
# Out:
#         State Total_Population  Total_Male_Population%  \
# 0     Alabama          4903185                   0.483
# 1      Alaska           731545                   0.520
# 2     Arizona          7278717                   0.497
# 3    Arkansas          3017804                   0.489
# 4  California         39512223                   0.497
#
#    Total_Female_Population%  Population_Under5%  Population5_17%  \
# 0                     0.517               0.058            0.163
# 1                     0.480               0.070            0.176
# 2                     0.503               0.059            0.167
# 3                     0.511               0.061            0.171
# 4                     0.503               0.060            0.165
#
#    Population18_24%  Population25_34%  Population35_44%  Population45_54%  \
# 0             0.093             0.130             0.124             0.124
# 1             0.093             0.161             0.127             0.120
# 2             0.095             0.138             0.123             0.117
# 3             0.094             0.128             0.125             0.120
# 4             0.093             0.153             0.134             0.126
#
#    ...  High_School_Graduate%  Some_College_or_Associate Degree%  \
# 0  ...                  0.309                              0.298
# 1  ...                  0.287                              0.346
# 2  ...                  0.237                              0.337
# 3  ...                  0.349                              0.293
# 4  ...                  0.206                              0.284
#
#    Bachelor_Degree%  Graduate_Or_Professional_Degree%  UnemploymentRate%  \
# 0             0.163                             0.100              0.049
# 1             0.185                             0.117              0.058
# 2             0.188                             0.113              0.051
# 3             0.151                             0.083              0.048
# 4             0.219                             0.131              0.051
#
#    Private_Health_Insurance%  Public_Health_Insurance_Coverage%  \
# 0                      0.669                              0.373
# 1                      0.648                              0.352
# 2                      0.627                              0.384
# 3                      0.593                              0.440
# 4                      0.639                              0.378
#
#    No_Health_Insurance_Coverage%  Povery_Rate%  Year
# 0                          0.097         0.155  2020
# 1                          0.122         0.101  2020
# 2                          0.113         0.135  2020
# 3                          0.091         0.162  2020
# 4                          0.077         0.118  2020
#
# [5 rows x 24 columns]

# %%
# make integer columns
demographics['Total_Population'] = demographics['Total_Population'].astype(int)
demographics['Year'] = demographics['Year'].astype(int)

# %%
# ensuring correct variable types
demographics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 204 entries, 0 to 50
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   State                              204 non-null    object
#  1   Total_Population                   204 non-null    int64
#  2   Total_Male_Population%             204 non-null    float64
#  3   Total_Female_Population%           204 non-null    float64
#  4   Population_Under5%                 204 non-null    float64
#  5   Population5_17%                    204 non-null    float64
#  6   Population18_24%                   204 non-null    float64
#  7   Population25_34%                   204 non-null    float64
#  8   Population35_44%                   204 non-null    float64
#  9   Population45_54%                   204 non-null    float64
#  10  Population55_64%                   204 non-null    float64
#  11  Population65_74%                   204 non-null    float64
#  12  Population_Over75%                 204 non-null    float64
#  13  Less_Than_High_School_Diploma%     204 non-null    float64
#  14  High_School_Graduate%              204 non-null    float64
#  15  Some_College_or_Associate Degree%  204 non-null    float64
#  16  Bachelor_Degree%                   204 non-null    float64
#  17  Graduate_Or_Professional_Degree%   204 non-null    float64
#  18  UnemploymentRate%                  204 non-null    float64
#  19  Private_Health_Insurance%          204 non-null    float64
#  20  Public_Health_Insurance_Coverage%  204 non-null    float64
#  21  No_Health_Insurance_Coverage%      204 non-null    float64
#  22  Povery_Rate%                       204 non-null    float64
#  23  Year                               204 non-null    int64
# dtypes: float64(21), int64(2), object(1)
# memory usage: 39.8+ KB

# %%
# merge into the previous merged dataset

merged_data_updated2 = pd.merge(
    merged_data_updated,
    demographics,
    left_on=['Geography', 'Year'],
    right_on=['State', 'Year'],
    how='left'
)

merged_data_updated2.head()
# Out:
#    Year Quarter   Geography  Pct_Telehealth   Real_GDP       State  \
# 0  2020       1     Alabama          0.0554   222288.8     Alabama
# 1  2020       1      Alaska          0.0758    50332.8      Alaska
# 2  2020       1     Arizona          0.0617   365027.7     Arizona
# 3  2020       1    Arkansas          0.0472   128340.9    Arkansas
# 4  2020       1  California          0.0915  2933320.2  California
#
#    Total_Population  Total_Male_Population%  Total_Female_Population%  \
# 0           4903185                   0.483                     0.517
# 1            731545                   0.520                     0.480
# 2           7278717                   0.497                     0.503
# 3           3017804                   0.489                     0.511
# 4          39512223                   0.497                     0.503
#
#    Population_Under5%  ...  Less_Than_High_School_Diploma%  \
# 0               0.058  ...                           0.129
# 1               0.070  ...                           0.064
# 2               0.059  ...                           0.124
# 3               0.061  ...                           0.125
# 4               0.060  ...                           0.160
#
#    High_School_Graduate%  Some_College_or_Associate Degree%  Bachelor_Degree%  \
# 0                  0.309                              0.298             0.163
# 1                  0.287                              0.346             0.185
# 2                  0.237                              0.337             0.188
# 3                  0.349                              0.293             0.151
# 4                  0.206                              0.284             0.219
#
#    Graduate_Or_Professional_Degree%  UnemploymentRate%  \
# 0                             0.100              0.049
# 1                             0.117              0.058
# 2                             0.113              0.051
# 3                             0.083              0.048
# 4                             0.131              0.051
#
#    Private_Health_Insurance%  Public_Health_Insurance_Coverage%  \
# 0                      0.669                              0.373
# 1                      0.648                              0.352
# 2                      0.627                              0.384
# 3                      0.593                              0.440
# 4                      0.639                              0.378
#
#    No_Health_Insurance_Coverage%  Povery_Rate%
# 0                          0.097         0.155
# 1                          0.122         0.101
# 2                          0.113         0.135
# 3                          0.091         0.162
# 4                          0.077         0.118
#
# [5 rows x 28 columns]

# %%
merged_data_updated2.shape
# Out:
# (816, 28)

# %%
# drop State from dataset
merged_data_updated2.drop(columns=['State'], inplace=True)

# %% [markdown]
# ## **Racial/Ethnicities Variables**

# %%
# Race / Ethnicity Data sets

# writing lists for looping and renaming purposes
filenames2 = ['2019_Ethnicities.csv', '2021_Ethnicities.csv', '2022_Ethnicities.csv', '2023_Ethnicities.csv']
years2 = ['2020', '2021', '2022', '2023']

datasets2 = {}

# Iterate through filenames and years simultaneously
for file, year in zip(filenames2, years2):
    datasets2[year] = pd.read_csv(file, skiprows=2, nrows=53)

    # remove rows where Location is United States and Puerto Rico
    datasets2[year] = datasets2[year][~datasets2[year]['Location'].isin(['United States', 'Puerto Rico'])]

    # remove columns Total and Footnotes
    datasets2[year] = datasets2[year].drop(['Total', 'Footnotes'], axis=1)

    # create a new column with the year
    datasets2[year]['Year'] = year

# append together dataframes
Ethnicities2020 = datasets2['2020']
Ethnicities2021 = datasets2['2021']
Ethnicities2022 = datasets2['2022']
Ethnicities2023 = datasets2['2023']

# Append/stack rows
Ethnicities = pd.concat([Ethnicities2020, Ethnicities2021, Ethnicities2022, Ethnicities2023], axis=0)

# %%
Ethnicities.isna().sum() / len(Ethnicities)
# Out:
# Location                               0.000000
# White                                  0.000000
# Black                                  0.000000
# Hispanic                               0.000000
# Asian                                  0.000000
# American Indian or Alaska Native       0.083333
# Native Hawaiian or Pacific Islander    0.568627
# Multiple Races                         0.000000
# Year                                   0.000000
# dtype: float64

# %%
# handling missing values

# delete Native Hawaiian or Pacific Islander column since there is 50% missing data
Ethnicities.drop('Native Hawaiian or Pacific Islander', axis=1, inplace = True)

# impute the American Indian or Alaska Native column with the median
median_value = Ethnicities['American Indian or Alaska Native'].median()
Ethnicities['American Indian or Alaska Native'].fillna(median_value, inplace=True)
# Out:
# <ipython-input-89-e0700101adfd>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Ethnicities['American Indian or Alaska Native'].fillna(median_value, inplace=True)

# %%
# ensure correct data type
Ethnicities['Year'] = Ethnicities['Year'].astype(int)

# %%
# rename the Ethnicities columns so it is applied that all columns are in percentage format
new_column_names = {'White': 'White%', 'Black': 'Black%', 'Hispanic': 'Hispanic%',
                    'Asian': 'Asian%', 'American Indian or Alaska Native': 'American_Indian_or_Alaska_Native%',
                    'Multiple Races': 'Multiple_Races%'}

# %%
# Rename all columns using the rename function
Ethnicities = Ethnicities.rename(columns=new_column_names)

# %%
# merge into the previous merged dataset

merged_data_updated3 = pd.merge(
    merged_data_updated2,
    Ethnicities,
    left_on=['Geography', 'Year'],
    right_on=['Location', 'Year'],
    how='left'
)

merged_data_updated3.head()
# Out:
#    Year Quarter   Geography  Pct_Telehealth   Real_GDP  Total_Population  \
# 0  2020       1     Alabama          0.0554   222288.8           4903185
# 1  2020       1      Alaska          0.0758    50332.8            731545
# 2  2020       1     Arizona          0.0617   365027.7           7278717
# 3  2020       1    Arkansas          0.0472   128340.9           3017804
# 4  2020       1  California          0.0915  2933320.2          39512223
#
#    Total_Male_Population%  Total_Female_Population%  Population_Under5%  \
# 0                   0.483                     0.517               0.058
# 1                   0.520                     0.480               0.070
# 2                   0.497                     0.503               0.059
# 3                   0.489                     0.511               0.061
# 4                   0.497                     0.503               0.060
#
#    Population5_17%  ...  Public_Health_Insurance_Coverage%  \
# 0            0.163  ...                              0.373
# 1            0.176  ...                              0.352
# 2            0.167  ...                              0.384
# 3            0.171  ...                              0.440
# 4            0.165  ...                              0.378
#
#    No_Health_Insurance_Coverage%  Povery_Rate%    Location  White%  Black%  \
# 0                          0.097         0.155     Alabama   0.654   0.265
# 1                          0.122         0.101      Alaska   0.600   0.022
# 2                          0.113         0.135     Arizona   0.542   0.043
# 3                          0.091         0.162    Arkansas   0.721   0.152
# 4                          0.077         0.118  California   0.364   0.053
#
#    Hispanic%  Asian%  American_Indian_or_Alaska_Native%  Multiple_Races%
# 0      0.044   0.014                              0.004            0.019
# 1      0.070   0.060                              0.151            0.083
# 2      0.318   0.033                              0.039            0.024
# 3      0.078   0.016                              0.006            0.024
# 4      0.395   0.147                              0.004            0.033
#
# [5 rows x 34 columns]

# %%
# drop Location column
merged_data_updated3.drop(columns=['Location'], inplace=True)

# %%
merged_data_updated3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 33 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Year                               816 non-null    int64
#  1   Quarter                            816 non-null    object
#  2   Geography                          816 non-null    object
#  3   Pct_Telehealth                     816 non-null    float64
#  4   Real_GDP                           816 non-null    float64
#  5   Total_Population                   816 non-null    int64
#  6   Total_Male_Population%             816 non-null    float64
#  7   Total_Female_Population%           816 non-null    float64
#  8   Population_Under5%                 816 non-null    float64
#  9   Population5_17%                    816 non-null    float64
#  10  Population18_24%                   816 non-null    float64
#  11  Population25_34%                   816 non-null    float64
#  12  Population35_44%                   816 non-null    float64
#  13  Population45_54%                   816 non-null    float64
#  14  Population55_64%                   816 non-null    float64
#  15  Population65_74%                   816 non-null    float64
#  16  Population_Over75%                 816 non-null    float64
#  17  Less_Than_High_School_Diploma%     816 non-null    float64
#  18  High_School_Graduate%              816 non-null    float64
#  19  Some_College_or_Associate Degree%  816 non-null    float64
#  20  Bachelor_Degree%                   816 non-null    float64
#  21  Graduate_Or_Professional_Degree%   816 non-null    float64
#  22  UnemploymentRate%                  816 non-null    float64
#  23  Private_Health_Insurance%          816 non-null    float64
#  24  Public_Health_Insurance_Coverage%  816 non-null    float64
#  25  No_Health_Insurance_Coverage%      816 non-null    float64
#  26  Povery_Rate%                       816 non-null    float64
#  27  White%                             816 non-null    float64
#  28  Black%                             816 non-null    float64
#  29  Hispanic%                          816 non-null    float64
#  30  Asian%                             816 non-null    float64
#  31  American_Indian_or_Alaska_Native%  816 non-null    float64
#  32  Multiple_Races%                    816 non-null    float64
# dtypes: float64(29), int64(2), object(2)
# memory usage: 210.5+ KB

# %%
# add a column for the region that the state is in
# Dictionary mapping states to regions
state_to_region = {
    'West': ['California', 'Oregon', 'Washington', 'Nevada', 'Idaho', 'Montana',
             'Wyoming', 'Utah', 'Colorado', 'Alaska', 'Hawaii'],
    'Southwest': ['Arizona', 'New Mexico', 'Oklahoma', 'Texas'],
    'Midwest': ['Illinois', 'Indiana', 'Iowa', 'Kansas', 'Michigan', 'Minnesota',
                'Missouri', 'Nebraska', 'North Dakota', 'Ohio', 'South Dakota', 'Wisconsin'],
    'South': ['Alabama', 'Arkansas', 'Florida', 'Georgia', 'Kentucky', 'Louisiana',
              'Mississippi', 'North Carolina', 'South Carolina', 'Tennessee', 'Virginia', 'West Virginia'],
    'Northeast': ['Connecticut', 'Maine', 'Massachusetts', 'New Hampshire', 'Maryland', 'Delaware',
                  'New Jersey', 'New York', 'Pennsylvania', 'Rhode Island', 'Vermont', 'District of Columbia']
}

# Map states to regions
merged_data_updated3['Region'] = merged_data_updated3['Geography'].map(state_to_region)

# %%
# Reverse the mapping to create a one-to-one mapping for states to regions
state_to_region_flat = {state: region for region, states in state_to_region.items() for state in states}

# Map states to regions
merged_data_updated3['Region'] = merged_data_updated3['Geography'].map(state_to_region_flat)

# %% [markdown]
# ## **Sentiment Analysis**

# %%
# !pip install pymongo

from pymongo import MongoClient
import pandas as pd

client = MongoClient('mongodb://carasgg:farmerbigdata@mongodb.fsb.miamioh.edu:27017', authSource="admin")

db= client['carasgg'] # replace YourMUID is your MUID

collection = db["list1"]

# Fetch all documents from the collection
documents = list(collection.find())

# Convert MongoDB documents to a Pandas DataFrame
list1 = pd.DataFrame(documents)

# Optionally, remove the MongoDB '_id' field if not needed
if '_id' in list1.columns:
    list1.drop('_id', axis=1, inplace=True)

# Display the DataFrame
print(list1.head())

# %%
client = MongoClient('mongodb://carasgg:farmerbigdata@mongodb.fsb.miamioh.edu:27017', authSource="admin")

db= client['carasgg'] # replace YourMUID is your MUID

collection = db["list2"]

# Fetch all documents from the collection
documents = list(collection.find())

# Convert MongoDB documents to a Pandas DataFrame
list2 = pd.DataFrame(documents)

# Optionally, remove the MongoDB '_id' field if not needed
if '_id' in list2.columns:
    list2.drop('_id', axis=1, inplace=True)

# Display the DataFrame
print(list2.head())

# %%
client = MongoClient('mongodb://carasgg:farmerbigdata@mongodb.fsb.miamioh.edu:27017', authSource="admin")

db= client['carasgg'] # replace YourMUID is your MUID

collection = db["list3"]

# Fetch all documents from the collection
documents = list(collection.find())

# Convert MongoDB documents to a Pandas DataFrame
list3 = pd.DataFrame(documents)

# Optionally, remove the MongoDB '_id' field if not needed
if '_id' in list3.columns:
    list3.drop('_id', axis=1, inplace=True)

# Display the DataFrame
print(list3.head())

# %%
client = MongoClient('mongodb://carasgg:farmerbigdata@mongodb.fsb.miamioh.edu:27017', authSource="admin")

db= client['carasgg'] # replace YourMUID is your MUID

collection = db["list4"]

# Fetch all documents from the collection
documents = list(collection.find())

# Convert MongoDB documents to a Pandas DataFrame
list4 = pd.DataFrame(documents)

# Optionally, remove the MongoDB '_id' field if not needed
if '_id' in list4.columns:
    list4.drop('_id', axis=1, inplace=True)

# Display the DataFrame
print(list4.head())

# %%
client = MongoClient('mongodb://carasgg:farmerbigdata@mongodb.fsb.miamioh.edu:27017', authSource="admin")

db= client['carasgg'] # replace YourMUID is your MUID

collection = db["list5"]

# Fetch all documents from the collection
documents = list(collection.find())

# Convert MongoDB documents to a Pandas DataFrame
list5 = pd.DataFrame(documents)

# Optionally, remove the MongoDB '_id' field if not needed
if '_id' in list5.columns:
    list5.drop('_id', axis=1, inplace=True)

# Display the DataFrame
print(list5.head())

# %%
# rename merged_data_updated3 to final
final = merged_data_updated3.copy()

# %%
# Put all DataFrames into a list
dataframes = [list1, list2, list3, list4, list5]

# Concatenate them row-wise
final_list = pd.concat(dataframes, ignore_index=True)

# %%
final_list['Year'] = final_list['Year'].astype(int)

# %%
final_list
# Out:
#         State  Year Quarter                                               Text
# 0     Alabama  2020      Q1  The move empowers the government to lock down ...
# 1     Alabama  2020      Q1  Across the country, it’s mostly business as us...
# 2     Alabama  2020      Q1  The spending package dwarfs what the Trump adm...
# 3     Alabama  2020      Q1  Should you wear a mask? Does airplane travel p...
# 4     Alabama  2020      Q1  Some tests distributed by the agency deliver “...
# ...       ...   ...     ...                                                ...
# 8106  Wyoming  2023      Q4  Jeanine Tesori and George Brant’s “Grounded,” ...
# 8107  Wyoming  2023      Q4  When not driving around, electric buses and ot...
# 8108  Wyoming  2023      Q4  How Adidas looked past misconduct in its partn...
# 8109  Wyoming  2023      Q4  The Natural Resources Defense Council is elimi...
# 8110  Wyoming  2023      Q4  What would you do if you won the lottery? How ...
#
# [8111 rows x 4 columns]

# %%
final_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8111 entries, 0 to 8110
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   State    8111 non-null   object
#  1   Year     8111 non-null   int64
#  2   Quarter  8111 non-null   object
#  3   Text     8111 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 253.6+ KB

# %%
corpus = final_list['Text']

corpus = corpus.astype(str)

# %%
# import nltk vader library
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# initiate an analyzer
sia = SentimentIntensityAnalyzer()

senti_pos = []
senti_neg = []
senti_neu = []
senti_comp = []


# iterate through each sentence in corpus
for sentence in corpus:

    #print(sentence)

    # analyze the sentiment. ss is a dictionary
    ss = sia.polarity_scores(sentence)

    # output each sentiment score (neg, neu, pos, compound) in ss
    #print(ss['pos']) # for debugging
    senti_pos.append(ss['pos'])
    senti_neg.append(ss['neg'])
    senti_neu.append(ss['neu'])
    senti_comp.append(ss['compound'])

    # print an empty line as seperator
    #print('\n')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
final_list = final_list.assign(pos = senti_pos, neg = senti_neg, neu = senti_neu, compound = senti_comp)

final_list
# Out:
#         State  Year Quarter  \
# 0     Alabama  2020      Q1
# 1     Alabama  2020      Q1
# 2     Alabama  2020      Q1
# 3     Alabama  2020      Q1
# 4     Alabama  2020      Q1
# ...       ...   ...     ...
# 8106  Wyoming  2023      Q4
# 8107  Wyoming  2023      Q4
# 8108  Wyoming  2023      Q4
# 8109  Wyoming  2023      Q4
# 8110  Wyoming  2023      Q4
#
#                                                    Text    pos    neg    neu  \
# 0     The move empowers the government to lock down ...  0.000  0.041  0.959
# 1     Across the country, it’s mostly business as us...  0.191  0.062  0.747
# 2     The spending package dwarfs what the Trump adm...  0.144  0.207  0.649
# 3     Should you wear a mask? Does airplane travel p...  0.109  0.089  0.802
# 4     Some tests distributed by the agency deliver “...  0.000  0.000  1.000
# ...                                                 ...    ...    ...    ...
# 8106  Jeanine Tesori and George Brant’s “Grounded,” ...  0.123  0.115  0.762
# 8107  When not driving around, electric buses and ot...  0.156  0.036  0.808
# 8108  How Adidas looked past misconduct in its partn...  0.015  0.000  0.985
# 8109  The Natural Resources Defense Council is elimi...  0.161  0.129  0.710
# 8110  What would you do if you won the lottery? How ...  0.179  0.104  0.716
#
#       compound
# 0      -0.1027
# 1       0.8402
# 2      -0.5574
# 3       0.2824
# 4       0.0000
# ...        ...
# 8106    0.1280
# 8107    0.8608
# 8108    0.0129
# 8109    0.0516
# 8110    0.6662
#
# [8111 rows x 8 columns]

# %%
# Group by State and calculate the mean for each sentiment column
state_quarter_avg_scores = final_list.groupby(['Year','State', 'Quarter'])[['pos', 'neu', 'neg', 'compound']].mean().reset_index()

# Display the results
state_quarter_avg_scores
# Out:
#      Year      State Quarter     pos     neu     neg  compound
# 0    2020    Alabama      Q1  0.0965  0.7927  0.1109  -0.01450
# 1    2020    Alabama      Q2  0.0749  0.7965  0.1287  -0.19299
# 2    2020    Alabama      Q3  0.1116  0.8149  0.0735   0.13934
# 3    2020    Alabama      Q4  0.0730  0.8705  0.0563   0.15929
# 4    2020     Alaska      Q1  0.0340  0.8955  0.0705  -0.18579
# ..    ...        ...     ...     ...     ...     ...       ...
# 811  2023  Wisconsin      Q4  0.0733  0.8733  0.0533   0.19950
# 812  2023    Wyoming      Q1  0.0730  0.8467  0.0806  -0.08449
# 813  2023    Wyoming      Q2  0.0920  0.8383  0.0697   0.08459
# 814  2023    Wyoming      Q3  0.0522  0.8758  0.0720  -0.05592
# 815  2023    Wyoming      Q4  0.1056  0.7927  0.1014   0.04741
#
# [816 rows x 7 columns]

# %%
state_quarter_avg_scores['Quarter'] = state_quarter_avg_scores['Quarter'].str.lstrip('Q')

state_quarter_avg_scores
# Out:
#      Year      State Quarter     pos     neu     neg  compound
# 0    2020    Alabama       1  0.0965  0.7927  0.1109  -0.01450
# 1    2020    Alabama       2  0.0749  0.7965  0.1287  -0.19299
# 2    2020    Alabama       3  0.1116  0.8149  0.0735   0.13934
# 3    2020    Alabama       4  0.0730  0.8705  0.0563   0.15929
# 4    2020     Alaska       1  0.0340  0.8955  0.0705  -0.18579
# ..    ...        ...     ...     ...     ...     ...       ...
# 811  2023  Wisconsin       4  0.0733  0.8733  0.0533   0.19950
# 812  2023    Wyoming       1  0.0730  0.8467  0.0806  -0.08449
# 813  2023    Wyoming       2  0.0920  0.8383  0.0697   0.08459
# 814  2023    Wyoming       3  0.0522  0.8758  0.0720  -0.05592
# 815  2023    Wyoming       4  0.1056  0.7927  0.1014   0.04741
#
# [816 rows x 7 columns]

# %%
merged_data_updated3 = merged_data_updated3.rename(columns={'Geography': 'State'})

merged_data_updated3['Quarter'] = merged_data_updated3['Quarter'].astype(str)

# %%
merged_data_updated3
# Out:
#      Year Quarter          State  Pct_Telehealth   Real_GDP  Total_Population  \
# 0    2020       1        Alabama          0.0554   222288.8           4903185
# 1    2020       1         Alaska          0.0758    50332.8            731545
# 2    2020       1        Arizona          0.0617   365027.7           7278717
# 3    2020       1       Arkansas          0.0472   128340.9           3017804
# 4    2020       1     California          0.0915  2933320.2          39512223
# ..    ...     ...            ...             ...        ...               ...
# 811  2023       4       Virginia          0.1042   597597.1           8715698
# 812  2023       4     Washington          0.1304   677238.0           7812880
# 813  2023       4  West Virginia          0.0943    80798.2           1770071
# 814  2023       4      Wisconsin          0.0937   344570.8           5910955
# 815  2023       4        Wyoming          0.0689    40210.8            584057
#
#      Total_Male_Population%  Total_Female_Population%  Population_Under5%  \
# 0                     0.483                     0.517               0.058
# 1                     0.520                     0.480               0.070
# 2                     0.497                     0.503               0.059
# 3                     0.489                     0.511               0.061
# 4                     0.497                     0.503               0.060
# ..                      ...                       ...                 ...
# 811                   0.494                     0.506               0.055
# 812                   0.504                     0.496               0.053
# 813                   0.499                     0.501               0.049
# 814                   0.501                     0.499               0.052
# 815                   0.506                     0.494               0.052
#
#      Population5_17%  ...  Public_Health_Insurance_Coverage%  \
# 0              0.163  ...                              0.373
# 1              0.176  ...                              0.352
# 2              0.167  ...                              0.384
# 3              0.171  ...                              0.440
# 4              0.165  ...                              0.378
# ..               ...  ...                                ...
# 811            0.160  ...                              0.349
# 812            0.157  ...                              0.365
# 813            0.149  ...                              0.473
# 814            0.158  ...                              0.360
# 815            0.170  ...                              0.332
#
#      No_Health_Insurance_Coverage%  Povery_Rate%  White%  Black%  Hispanic%  \
# 0                            0.097         0.155   0.654   0.265      0.044
# 1                            0.122         0.101   0.600   0.022      0.070
# 2                            0.113         0.135   0.542   0.043      0.318
# 3                            0.091         0.162   0.721   0.152      0.078
# 4                            0.077         0.118   0.364   0.053      0.395
# ..                             ...           ...     ...     ...        ...
# 811                          0.064         0.102   0.583   0.179      0.111
# 812                          0.063         0.103   0.625   0.038      0.145
# 813                          0.059         0.167   0.902   0.026      0.020
# 814                          0.049         0.107   0.787   0.057      0.081
# 815                          0.107         0.113   0.815   0.006      0.107
#
#      Asian%  American_Indian_or_Alaska_Native%  Multiple_Races%     Region
# 0     0.014                              0.004            0.019      South
# 1     0.060                              0.151            0.083       West
# 2     0.033                              0.039            0.024  Southwest
# 3     0.016                              0.006            0.024      South
# 4     0.147                              0.004            0.033       West
# ..      ...                                ...              ...        ...
# 811   0.070                              0.001            0.056      South
# 812   0.099                              0.008            0.078       West
# 813   0.007                              0.004            0.044      South
# 814   0.029                              0.005            0.040    Midwest
# 815   0.006                              0.016            0.050       West
#
# [816 rows x 34 columns]

# %%
final_df = pd.merge(merged_data_updated3, state_quarter_avg_scores[['Year','State', 'Quarter', 'pos', 'neu', 'neg', 'compound']],
               on=['Year','State', 'Quarter'], how='left')

final_df
# Out:
#      Year Quarter          State  Pct_Telehealth   Real_GDP  Total_Population  \
# 0    2020       1        Alabama          0.0554   222288.8           4903185
# 1    2020       1         Alaska          0.0758    50332.8            731545
# 2    2020       1        Arizona          0.0617   365027.7           7278717
# 3    2020       1       Arkansas          0.0472   128340.9           3017804
# 4    2020       1     California          0.0915  2933320.2          39512223
# ..    ...     ...            ...             ...        ...               ...
# 811  2023       4       Virginia          0.1042   597597.1           8715698
# 812  2023       4     Washington          0.1304   677238.0           7812880
# 813  2023       4  West Virginia          0.0943    80798.2           1770071
# 814  2023       4      Wisconsin          0.0937   344570.8           5910955
# 815  2023       4        Wyoming          0.0689    40210.8            584057
#
#      Total_Male_Population%  Total_Female_Population%  Population_Under5%  \
# 0                     0.483                     0.517               0.058
# 1                     0.520                     0.480               0.070
# 2                     0.497                     0.503               0.059
# 3                     0.489                     0.511               0.061
# 4                     0.497                     0.503               0.060
# ..                      ...                       ...                 ...
# 811                   0.494                     0.506               0.055
# 812                   0.504                     0.496               0.053
# 813                   0.499                     0.501               0.049
# 814                   0.501                     0.499               0.052
# 815                   0.506                     0.494               0.052
#
#      Population5_17%  ...  Black%  Hispanic%  Asian%  \
# 0              0.163  ...   0.265      0.044   0.014
# 1              0.176  ...   0.022      0.070   0.060
# 2              0.167  ...   0.043      0.318   0.033
# 3              0.171  ...   0.152      0.078   0.016
# 4              0.165  ...   0.053      0.395   0.147
# ..               ...  ...     ...        ...     ...
# 811            0.160  ...   0.179      0.111   0.070
# 812            0.157  ...   0.038      0.145   0.099
# 813            0.149  ...   0.026      0.020   0.007
# 814            0.158  ...   0.057      0.081   0.029
# 815            0.170  ...   0.006      0.107   0.006
#
#      American_Indian_or_Alaska_Native%  Multiple_Races%     Region     pos  \
# 0                                0.004            0.019      South  0.0965
# 1                                0.151            0.083       West  0.0340
# 2                                0.039            0.024  Southwest  0.0764
# 3                                0.006            0.024      South  0.0742
# 4                                0.004            0.033       West  0.1210
# ..                                 ...              ...        ...     ...
# 811                              0.001            0.056      South  0.0307
# 812                              0.008            0.078       West  0.0685
# 813                              0.004            0.044      South  0.0399
# 814                              0.005            0.040    Midwest  0.0733
# 815                              0.016            0.050       West  0.1056
#
#         neu     neg  compound
# 0    0.7927  0.1109  -0.01450
# 1    0.8955  0.0705  -0.18579
# 2    0.8259  0.0977  -0.16932
# 3    0.8370  0.0889   0.02960
# 4    0.8126  0.0665   0.07139
# ..      ...     ...       ...
# 811  0.9059  0.0634  -0.12002
# 812  0.8366  0.0949  -0.13560
# 813  0.8414  0.1186  -0.43365
# 814  0.8733  0.0533   0.19950
# 815  0.7927  0.1014   0.04741
#
# [816 rows x 38 columns]

# %%
final_df.to_csv('final_df.csv', index=False)

# %% [markdown]
# ## **Descriptive Analysis**

# %%
# no missing values
import pandas as pd
final_df = pd.read_csv('https://raw.githubusercontent.com/Mar-abaas/Telehealth/refs/heads/main/final_df.csv')
final_df.isna().sum()
# Out:
# Year                                 0
# Quarter                              0
# State                                0
# Pct_Telehealth                       0
# Real_GDP                             0
# Total_Population                     0
# Total_Male_Population%               0
# Total_Female_Population%             0
# Population_Under5%                   0
# Population5_17%                      0
# Population18_24%                     0
# Population25_34%                     0
# Population35_44%                     0
# Population45_54%                     0
# Population55_64%                     0
# Population65_74%                     0
# Population_Over75%                   0
# Less_Than_High_School_Diploma%       0
# High_School_Graduate%                0
# Some_College_or_Associate Degree%    0
# Bachelor_Degree%                     0
# Graduate_Or_Professional_Degree%     0
# UnemploymentRate%                    0
# Private_Health_Insurance%            0
# Public_Health_Insurance_Coverage%    0
# No_Health_Insurance_Coverage%        0
# Povery_Rate%                         0
# White%                               0
# Black%                               0
# Hispanic%                            0
# Asian%                               0
# American_Indian_or_Alaska_Native%    0
# Multiple_Races%                      0
# Region                               0
# pos                                  0
# neu                                  0
# neg                                  0
# compound                             0
# dtype: int64

# %%
# summary statistics for response variable
final_df['Pct_Telehealth'].describe()
# Out:
# count    816.000000
# mean       0.174508
# std        0.109541
# min        0.035200
# 25%        0.094525
# 50%        0.147850
# 75%        0.217300
# max        0.734700
# Name: Pct_Telehealth, dtype: float64

# %%
# Grouping by quarter for Pct_Telehealth
quarterly_usage = final_df.groupby(['Year', 'Quarter'])['Pct_Telehealth'].mean().reset_index()
quarterly_usage
# Out:
#     Year  Quarter  Pct_Telehealth
# 0   2020        1        0.065745
# 1   2020        2        0.450631
# 2   2020        3        0.261990
# 3   2020        4        0.267661
# 4   2021        1        0.252380
# 5   2021        2        0.169190
# 6   2021        3        0.148188
# 7   2021        4        0.145969
# 8   2022        1        0.173251
# 9   2022        2        0.137365
# 10  2022        3        0.133545
# 11  2022        4        0.133082
# 12  2023        1        0.126786
# 13  2023        2        0.109190
# 14  2023        3        0.106288
# 15  2023        4        0.110863

# %%
# State-level comparison for telehealth usage and Pct_Telehealth
state_comparison = final_df.groupby('State')[['Pct_Telehealth']].mean().reset_index()

# Sort by Pct_Telehealth in descending order
state_comparison = state_comparison.sort_values(by='Pct_Telehealth', ascending=False).reset_index(drop=True)

state_comparison
# Out:
#                    State  Pct_Telehealth
# 0          Massachusetts        0.310681
# 1             California        0.310444
# 2   District of Columbia        0.269612
# 3           Rhode Island        0.259537
# 4                 Hawaii        0.255144
# 5               Maryland        0.238975
# 6               New York        0.237594
# 7               Delaware        0.233356
# 8            Connecticut        0.226944
# 9             New Mexico        0.224837
# 10            New Jersey        0.221062
# 11               Vermont        0.218631
# 12             Minnesota        0.217963
# 13         New Hampshire        0.216681
# 14                Oregon        0.208531
# 15                Alaska        0.207069
# 16               Arizona        0.205394
# 17              Michigan        0.203931
# 18                 Texas        0.198894
# 19                Nevada        0.186287
# 20              Colorado        0.184737
# 21                 Maine        0.182031
# 22          Pennsylvania        0.180906
# 23            Washington        0.178344
# 24               Florida        0.173956
# 25              Illinois        0.164544
# 26         West Virginia        0.161863
# 27              Virginia        0.161475
# 28                  Ohio        0.159444
# 29              Kentucky        0.152350
# 30        North Carolina        0.149450
# 31             Wisconsin        0.148444
# 32               Georgia        0.144519
# 33                  Utah        0.142712
# 34              Oklahoma        0.141113
# 35               Indiana        0.139513
# 36              Arkansas        0.136181
# 37               Alabama        0.124856
# 38        South Carolina        0.122762
# 39             Louisiana        0.122006
# 40              Missouri        0.117725
# 41                 Idaho        0.116669
# 42           Mississippi        0.116500
# 43               Montana        0.110394
# 44                Kansas        0.110287
# 45               Wyoming        0.106806
# 46                  Iowa        0.105387
# 47          South Dakota        0.104744
# 48             Tennessee        0.103600
# 49              Nebraska        0.095231
# 50          North Dakota        0.089781

# %%
# Top 10 and Bottom 10 states by telehealth percentage
top_states = state_comparison.head(10)
top_states
# Out:
#                   State  Pct_Telehealth
# 0         Massachusetts        0.310681
# 1            California        0.310444
# 2  District of Columbia        0.269612
# 3          Rhode Island        0.259537
# 4                Hawaii        0.255144
# 5              Maryland        0.238975
# 6              New York        0.237594
# 7              Delaware        0.233356
# 8           Connecticut        0.226944
# 9            New Mexico        0.224837

# %%
bottom_states = state_comparison.tail(10)
bottom_states
# Out:
#            State  Pct_Telehealth
# 41         Idaho        0.116669
# 42   Mississippi        0.116500
# 43       Montana        0.110394
# 44        Kansas        0.110287
# 45       Wyoming        0.106806
# 46          Iowa        0.105387
# 47  South Dakota        0.104744
# 48     Tennessee        0.103600
# 49      Nebraska        0.095231
# 50  North Dakota        0.089781

# %%
import matplotlib.pyplot as plt

quarterly_usage['Year-Quarter'] = quarterly_usage['Year'].astype(str) + ' Q' + quarterly_usage['Quarter'].astype(str)

# Plot the line chart
plt.figure(figsize=(10, 6))
plt.plot(quarterly_usage['Year-Quarter'], quarterly_usage['Pct_Telehealth'], marker='o', linestyle='-')
plt.xticks(rotation=45)
plt.title('Average Quarterly Telehealth Usage Over Time')
plt.xlabel('Year and Quarter')
plt.ylabel('Average % Telehealth Usage')
plt.grid(True)  # Use plt.grid(True) for better readability
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.barplot(data=top_states, x='Pct_Telehealth', y='State', palette='viridis')
plt.title('Top 10 States by Telehealth Percentage')
plt.xlabel('Average Pct Telehealth (%)')
plt.ylabel('State')
plt.show();
# Out:
# <ipython-input-11-0b304f726080>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_states, x='Pct_Telehealth', y='State', palette='viridis')

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=bottom_states, x='Pct_Telehealth', y='State', palette='coolwarm')
plt.title('Bottom 10 States by Telehealth Percentage')
plt.xlabel('Average Pct Telehealth (%)')
plt.ylabel('State')
plt.show();
# Out:
# <ipython-input-12-976178ecc2ed>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=bottom_states, x='Pct_Telehealth', y='State', palette='coolwarm')

# %% [markdown]
# After cleaning and pre-processing our data sets, we are left with final_df, which was output into a CSV file names `final_df.csv`. This is the dataset that we will input in the next file where we perform our modeling and analysis
